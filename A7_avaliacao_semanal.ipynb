# %% [markdown]
# # AS7 - ECD - Modelos de Regressão

# %% [markdown]
# ### Questão 1:<br>
#
# Sobre modelos lineares, podemos afirmar que:<br>
#
# Escolha uma opção:<br>
# a. As medidas DFFITS e Distância de Cook permitem identificar exclusivamente pontos de alavanca.<br>
# <font color='red'>b. Em um modelo de regressão linear multivariado, há “m” variáveis respostas associadas de forma linear (nos parâmetros) a “p” variáveis preditoras.</font><br>
# c. Os pontos de alavanca são outliers no espaço dos X e a sua exclusão sempre causa mudança inferencial no modelo.<br>
# d. No modelo de regressão linear simples, os estimadores de máxima verossimilhança dos coeficientes da regressão podem ser obtidos sem supor uma distribuição de probabilidade para os erros aleatórios.<br>
# e. Se uma variável preditora sozinha contribui com uma boa porção do coeficiente de determinação, ela deve ser a única variável preditora do modelo.<br>

# %% [markdown]
# a. Errado. As técnicas de DFFITS e Distância de Cook permitem identificar pontos influentes na inferência do modelo. <br>
# b. Certo. Regressão Linear Multivariada tem vários y como respostas a várias variáveis preditoras x. Os coeficientes (parâmetros) são lineares, mas x pode ser qualquer função.<br>
# c. Errado. Os pontos de alavanca são outliers no espaço dos X, mas não necessariamente têm impacto na inferência do modelo.<br>
# d. Errado. Os estimadores dos coeficientes de regressão podem ser obtidos pela máxima verossimilhança (EMV) se supormos que a distribuição dos erros é uma normal com média 0 e variância Gama.exp(2)* matriz identidade. <br>
# e. Errado. Uma variável preditora com boa contribuição pode ser usada em conjunto com outras variáveis preditoras para melhorar a qualidade do ajuste.<br>

# %% [markdown]
# ### Questão 2:<br>
#
# Considere os gráficos de resíduos abaixo e as afirmações a seguir:<br>
#
# ![AS7_ECD_Questao_2.png](attachment:AS7_ECD_Questao_2.png)
#
#
# I - Em (a), existe uma possível autocorrelação entre os erros, ou seja, a suposição de que são não-correlacionados pode estar incorreta.<br>
# II -  Em (b), pode ser necessário fazer uma transformação nos dados.<br>
# III - Em (c), não é possível identificar padrões nos resíduos, e portanto não temos evidências (pelo menos visualmente) de problemas nas suposições do modelo.<br>
#
# Estão corretas as afirmações:<br>
#
# Escolha uma opção:<br>
# a. III apenas<br>
# <font color='red'>b. I, II e III</font><br>
# c. I e II apenas<br>
# d. II apenas<br>
# e. I apenas<br>
# f. I e III apenas<br>

# %% [markdown]
# I. Certo. Existe uma possível autocorrelação, ou seja, um erro influencia o erro adjacente.<br>
# II. Certo. Possíveis soluções passam por adicionar termos extras ou transformar Y. Se o padrão observado no gráfico contra o tempo, testar a inclusão de termos lineares ou quadráticos no tempo.<br>
# III. Certo. Aparentemente o erro tem distribuição normal.<br>

# %% [markdown]
# ### Questão 3:<br>
#
# Considere os gráficos de resíduos abaixo e as afirmações:<br>

# %% [markdown]
# ![AS7_ECD_Questao_3.png](attachment:AS7_ECD_Questao_3.png)

# %% [markdown]
# I -  Em (a), é possível que a variância dos erros não seja constante, a chamada heterocedasticidade. Uma possível solução é transformar a variável resposta de forma a obter um comportamento homocedástico dos resíduos.<br>
# II -  Em (b), os pontos que se destacam são classificados como pontos de alavanca.<br>
# III - Em (c), pode existir erro na construção do modelo.<br>
#
# Estão corretas as afirmativas:<br>
#
# Escolha uma opção:<br>
# a. II apenas<br>
# b. I apenas<br>
# c. III apenas<br>
# d. I e II apenas<br>
# e. I, II e III<br>
# <font color='red'>f. I e III apenas</font><br>

# %% [markdown]
# I - Certo. Heterocedasticidade: variância dos erros não é constante. Possíveis soluções: mínimos quadrados ponderados e transformação em Y.<br>
# II - Errado. O valor extremo ou valor atípico (outlier) é uma observação com "alto" resíduo. Neste caso, temos uma observação cuja variável dependente é inesperada dado o valor da variável explicativa.  Por outro lado, dizemos que uma observação é um ponto de alavanca (ou leverage alto) se a variável explicativa é extrema. Quando temos apenas uma variável explicativa, um valor extremo significa um valor baixo e/ou alto para a variável explicativa. Se tivermos um vetor de variáveis explicativas, um ponto extremo significa uma combinação de valores inesperados para as variáveis explicativa. Assim, vamos utilizar o resíduo para detectar valores extremos na resposta e o ponto de alavanca para detectarmos valores extremos ou inesperados para a variável explicativa. http://www.portalaction.com.br/analise-de-regressao/34-pontos-influentes-e-valores-extremos <br>
# III - Certo. Rever modelo. Se o padrão for observado no gráfico contra o tempo, pode faltar termo linear no tempo. Se o padrão for observado no gráfico contra X, rever preditores.<br>

# %% [markdown]
# ### Questão 4:
#
# Sobre modelos lineares, assinale todas as afirmações corretas:<br>
#
# Escolha uma ou mais:<br>
# <font color='red'>a. A suposição de distribuição normal no modelo linear para os erros aleatórios implica na distribuição normal da variável resposta dados os preditores.</font><br>
# b. O estimador de máxima verossimilhança para o vetor de coeficientes da regressão linear supondo erros normais não possui boas propriedades estatísticas, já que é viesado porém consistente.<br>
# c. As métricas de ajuste “erro absoluto médio”, “erro quadrático médio” e “raiz do erro quadrático médio” são suficientes para verificar a presença de pontos atípicos na base de treinamento.<br>
# <font color='red'>d. A transformação de Box-Cox na variável resposta pode levar à melhor qualidade do modelo ajustado, que pode ser verificada com o auxílio da análise de resíduos.</font><br>
# <font color='red'>e. Espera-se que as variáveis preditoras não sejam fortemente correlacionadas, mas caso sejam, pode ser fundamental realizar uma seleção de variáveis para evitar problemas numéricos no ajuste de um modelo de regressão linear.</font><br>

# %% [markdown]
# a. Certo.  Y = X𝛽 + E e, fixando X𝛽, se E tem distribuição normal, então Y também tem distribuição normal. http://www.portalaction.com.br/analise-de-regressao/21-modelo-estatistico <br>
# b. Errado. O EMV de  𝛽  é não-viesado e consistente, que são boas propriedades estatísticas. <br>
# c. Errado. Essas são métricas importantes para avaliar a qualidade do ajuste, porém outras necessitam ser verificadas para observar a presença de outliers. Boxplot é um bom exemplo.  <br>
# d. Certo. Box-Cox é uma transformação na variável resposta com o objetivo de tentar melhorar a qualidade do modelo e pode ser verificada entre outras pela análise dos resíduos. Outros indicadores os boxplots para identificação de outliers e os métodos DFFITS e Distância de Cook para identificar pontos influentes no resultado do modelo.  <br>
# e. Certo. Em caso de variáveis preditoras fortemente correlacionadas é fundamental fazer uma seleção de variáveis para evitar problemas no ajuste do modelo.  <br>

# %% [markdown]
# ### Questão 5:<br>
# Considere um modelo de regressão linear múltipla para os dados Prestige da Prática 2, e os resultados abaixo obtidos em Python:<br>
#
# ![AS7_ECD_Questao_5.png](attachment:AS7_ECD_Questao_5.png)
#
# Assinale a alternativa incorreta:<br>
#
# Escolha uma opção:<br>
# a. A média da resposta “dados.prestige” quando todas as variáveis preditoras assumem zero é -110.9658.<br>
# <font color='red'>b. O coeficiente de determinação do modelo 0.835 indica um bom ajuste, o que dispensa a busca por modelos melhores.</font><br>
# c. O valor de AIC pode ser usado para comparar modelos lineares e selecionar variáveis, sendo que quanto menor o AIC, melhor o modelo ajustado.<br>
# d. O teste de hipóteses marginal para o coeficiente da variável “dados.women” indica que essa variável poderia ser excluída do modelo. Essa conclusão se confirma se olharmos para o intervalo de confiança para o parâmetro correspondente, [-0.012, 0.106], que contém o zero.<br>
# e. Quando fixadas as demais variáveis, o aumento de uma unidade na variável preditora “l_income” produz um aumento médio de 9.3147 unidades na variável resposta “dados.prestige”.<br>

# %% [markdown]
# a. Certo. Quando x=0, a variável preditora, então a resposta é o valor do intercepto.  <br>
# b. Errado. O coeficiente de determinação r2 é um bom indicador da qualidade do modelo, mas não significa que o mesmo não pode ser melhorado.  <br>
# c. Certo. AIC e BIC são métricas de qualidade do ajuste, e quanto menores melhor o ajuste. <br>
# d. Certo. O valor do coeficiente é 0.047 com dp=0.030, o que é alto. O valor zero para o coeficiente está no intervalo de valores possíveis: -0.012 a 0.106. Além disso, p-value = 0.120 que é > 0.005, portanto não rejeitamos H0 de que o coef.Beta=0. <br>
# e. Certo. O coeficiente Beta indica que a cada incremento de 1 unidade em x, o y crescerá (se Beta positivo) o valor do Beta em unidades. <br>
