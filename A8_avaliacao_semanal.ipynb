# %% [markdown]
# # AS8 - ECD - Modelos Lineares Generalizados

# %% [markdown]
# ### Questão 1:<br>
# Sobre modelos lineares generalizados, é incorreto afirmar que<br>
#
# Escolha uma opção:<br>
# a. No modelo Poisson, a função de ligação canônica é a log.<br>
# b. No modelo binomial, a função de ligação canônica é a logito.<br>
# c. A variável resposta tem distribuição na família exponencial.<br>
# d. A função de ligação permite a modelagem de funções da média da variável resposta utilizando parâmetros em um modelo linear, por isso esses modelos recebem o nome de modelos lineares generalizados.<br>
# <font color='red'>e. O modelo linear múltiplo não pode ser considerado um modelo linear generalizado.</font><br>

# %% [markdown]
# a. Certo. Função de ligação canônica(Eta) conforme a regra Teta(i) = Eta(i). Para Poisson: Eta = log mu  <br>
# b. Certo. Função de ligação canônica(Eta) conforme a regra Teta(i) = Eta(i). Para Binomial: Eta = log {mu/(1-mu)} que é chamada função logito.  <br>
# c. Certo. A distribuição de  𝑌𝑖  pertencente à família exponencial é descrita como 𝑌𝑖∼𝐹𝐸(𝜇𝑖,𝜙) <br>
# d. Certo. Para o MLG que e definido por 𝑌𝑖∼𝐹𝐸(𝜇𝑖,𝜙), a função de ligação 𝑔(𝜇𝑖) é definida como 𝑔(𝜇𝑖)=𝜂𝑖, onde 𝜂𝑖=𝑋⊤𝑖𝛽  é o preditor linear.  <br>
# e. Errado. O MLG pode ser estendido para incluir  𝑝  variáveis preditoras. <br>

# %% [markdown]
# ### Informação:<br>
#
# Um modelo de regressão logística foi ajustado para dados de internações por COVID-19. Nesse modelo, a variável resposta considerada foi óbito pela doença (1: sim, 0: não) e a presença de comorbidades como asma, cardiopatia, diabetes, doença renal, obesidade, entre outras (1: presença, 0: ausência), além do sexo (1: feminino, 0: masculino) e idade (em anos completos). Todas essas comorbidades foram incluídas como variáveis preditoras (mais o intercepto, idade e sexo) em um modelo linear generalizado com resposta binomial e o seguinte modelo foi obtido:<br>
#
# ![AS8_ECD_Informacao.png](attachment:AS8_ECD_Informacao.png)

# %% [markdown]
# ### Questão 2:<br>
# A comorbidade de maior significância marginal para óbitos por COVID-19, segundo esse modelo, é:<br>
#
# Escolha uma opção:<br>
# a. asma<br>
# b. cardiopatia<br>
# c. diabetes<br>
# <font color='red'>d. obesidade</font><br>
# e. doença renal<br>

# %% [markdown]
# Quanto menor o p-value (P>|z|), mas signficante é o atributo.<br>
# Normalmente a linha de corte é p-value = 0.05.<br>
# Rejeita-se H0 que é a hipótese de Beta do atributo = 0.<br>

# %% [markdown]
# ### Questão 3:<br>
# A comorbidade de menor significância marginal para óbitos por COVID-19, segundo esse modelo, é:<br>
#
# Escolha uma opção:<br>
# a. obesidade<br>
# b. diabetes<br>
# <font color='red'>c. cardiopatia</font><br>
# d. asma<br>
# e. doença renal<br>

# %% [markdown]
# Quanto maior o p-value (P>|z|), menos signficante é o atributo.<br>
# Normalmente a linha de corte é p-value = 0.05.<br>
# Aceita-se H0 que é a hipótese de Beta do atributo = 0.<br>

# %% [markdown]
# ### Questão 4:<br>
# Considerando que a chance é uma razão de probabilidades, e a razão de chances neste modelo pode ser calculada como OR=expβˆj, para cada j=1,…,7, em que βˆj é o coeficiente estimado da regressão correspondente à j−ésima preditora, a razão de chances para óbito por COVID-19 para um indivíduo que possui diabetes em relação a um que não possui, fixadas todas as outras preditoras, é:<br>
#
# Escolha uma opção:<br>
# a. 1.60<br>
# <font color='red'>b. 1.30</font><br>
# c. 1.23<br>
# d. 1.94<br>
# e. 0.27<br>

# %% [markdown]
# razão de chances: Opportunity Ratio
# OR = exp(Beta_diabetes)

# %%
import numpy as np
Beta_diabetes = 0.2654
OR = np.exp(Beta_diabetes)
OR.round(2)
# Out:
# 1.3

# %% [markdown]
# ### Questão 5:<br>
# Uma razão de chances igual a 1.94 significa, segundo o modelo ajustado, um aumento de que percentual na chance de vir a óbito por COVID-19?<br>
#
# Escolha uma opção:<br>
# a. 9,4%<br>
# b. 20%<br>
# c. 1.94%<br>
# d. 6%<br>
# <font color='red'>e. 94%</font><br>

# %% [markdown]
# OR = 1.94 significa 0.94 = 94% a mais de óbito na presença da comorbidade
