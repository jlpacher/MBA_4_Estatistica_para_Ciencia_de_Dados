# %% [markdown]
# # AS6 - ECD - INFERÊNCIA BAYESIANA

# %% [markdown]
# ### Questão 1:<br>
# Assinale a alternativa incorreta<br>
#
# Escolha uma opção:<br>
# a. Os parâmetros de um modelo estatístico são desconhecidos, porém o paradigma Bayesiano permite modelar a incerteza sobre eles por meio de distribuições de probabilidade, ou seja, assumindo que são quantidades aleatórias.<br>
# b. O conhecimento a priori do pesquisador é anterior à observação dos dados.<br>
# c. O Teorema de Bayes permite combinar as informações da distribuição a priori para os parâmetros com a verossimilhança, ou seja, a informação fornecida pelos dados.<br>
# d. A distribuição a posteriori dos parâmetros pode representar conhecimento a priori para a observação futura de novos dados de um mesmo experimento.<br>
# <font color = 'red'>e. A distribuição a posteriori do parâmetro é sempre exatamente igual ao produto da verossimilhança com a distribuição a priori dos parâmetros.</font><br>

# %% [markdown]
# A distribuição à posteriori é PROPORCIONAL ao produto da verossimilhança com a distribuição à priori dos parâmetros.<br>
# Essa proporção é representada por k, a constante normalizadora.

# %% [markdown]
# ### Questão 2:<br>
# Considere as afirmações abaixo<br>
#
#  I -  A distribuição preditiva pode fornecer evidências sobre a plausibilidade do modelo e das suposições a priori do pesquisador.<br>
# II - A inferência Bayesiana deve ser utilizada com muita cautela, pois se a priori for informativa e equivocada, o pesquisador pode introduzir um viés ao estimar os parâmetros.<br>
# III - É possível obter estimação pontual e estimação intervalar a partir da distribuição a posteriori dos parâmetros.<br>
# IV - Mesmo se a priori conjugada não faz sentido para um parâmetro, aconselha-se utilizar os modelos conjugados para se beneficiar da eficiência computacional.<br>
#
# São corretas as afirmações<br>
#
# Escolha uma opção:<br>
# a. apenas II e III<br>
# b. apenas I e III<br>
# <font color='red'>c. apenas I, II e III</font><br>
# d. todas<br>
# e. apenas I e II<br>

# %% [markdown]
# I-Verdadeiro<br>
# Distribuição preditiva refere-se à amostragem, ou seja,a verossimilhança.<br>
# Para  𝑥  fixo, a verossimilhança $l(\theta,x) = p(x|\theta)$ fornece a plausibilidade de cada um dos possíveis valores de  𝜃 .<br>
# Já a distribuição a priori  𝑝(𝜃)  incorpora o conhecimento do pesquisador.<br>
# Essas duas quantidades combinadas são levadas a $p(\theta|x)$, a distribuição a posteriori de  𝜃 .
#
# II-Verdadeiro<br>
# Apesar da sua grande utilidade, os métodos que serão apresentados aqui devem ser aplicados com cautela. Devido à facilidade com que os recursos computacionais podem ser utilizados hoje em dia, corremos o risco de apresentar uma solução para o problema errado (o erro tipo 3) ou uma solução ruim para o problema certo. Assim, os métodos computacionalmente intensivos não devem ser vistos como substitutos do pensamento crítico sobre o problema por parte do pesquisador.<br>
#
# Além disso, sempre que possível deve-se utilizar soluções exatas, i.e. não aproximadas, se elas existirem. Por exemplo, em muitas situações em que precisamos calcular uma integral múltipla existe solução exata em algumas dimensões, enquanto nas outras dimensões temos que usar métodos de aproximação.<br>
# http://www.leg.ufpr.br/~paulojus/CE227/ce227/node5.html#SECTION00510000000000000000
#
# III-Verdadeiro<br>
# É possível obter a estimação pontual (média) e também intervalar, chamada intervalo de credibilidade para um nível ($1-\alpha$) de confiança.<br>
# Pode-se desenvolver a estimação por intervalos por meio do intervalo de credibilidade (ou intervalo de confiança Bayesiano) baseado no distribuição a posteriori.<br>
# Definição:<br>
# C é um intervalo de credibilidade de 100(1-$\alpha$)$\%$, ou nível de credibilidade (ou confiança) $1-\alpha$, para $\theta$ se $P(\theta\in C)\ge 1-\alpha$.<br>
# Obs: Quanto menor for o tamanho do intervalo, mais concentrada é a distribuição do parâmetro, ou seja o tamanho do intervalo informa sobre a dispersão de $\theta$.
#
# IV-Falso<br>
# O uso de priori conjugada trás um grande benefício de eficiência computacional.<br>
# Porém o uso de uma priori que não faça sentido ou equivocada pode trazer um viés à posteriori e não deve ser usada.<br>
# As prioris não-informativas, uniforme ou vaga (às vezes imprópria) podem ser usadas.<br>
# Em geral a priori não informativa é obtida fazendo-se o parâmetro de escala da distribuição conjugada tender a zero e fixando-se os demais parâmetros convenientemente.<br>
# Uma análise deve ser feita para captar esta noção de uma priori que tenha um efeito mínimo, relativamente aos dados, na inferência final.

# %% [markdown]
# ### Questão 3:<br>
# [adaptado de Gelman, A., Carlin, J. B., Stern, H. S., Dunson, D. B., Vehtari, A., & Rubin, D. B. (2013). Bayesian data analysis. CRC press.]
#
# Sabe-se que aproximadamente 1/125 de todos os nascimentos são de gêmeos fraternos e 1/300 de todos os nascimentos são de gêmeos idênticos. Logo após um determinado nascimento de gêmeos do mesmo gênero, um dos bebês veio a óbito. Aproxime a probabilidade de nascimento de menino ou menina seja 1/2 cada e utilize as dicas abaixo para o item (a), se necessário.<br>
#
# (a) Qual a probabilidade que os gêmeos em questão sejam idênticos, dado que ambos são do sexo masculino?<br>
# (b) Se uma das probabilidades dadas fosse desconhecida, mas um pesquisador tivesse alguma crença sobre a sua incerteza, como essa informação poderia ser incorporada em um processo de modelagem probabilística?<br>
#
# Sugestão de resolução para o item (a):<br>
# A = {nascerem gêmeos idênticos}<br>
# B = {nascerem gêmeos fraternos}<br>
# C = {nascerem gêmeos do sexo masculino}<br>
#
# Tem-se que:<br>
# P(A) = 1/300, P(B) = 1/125, P(C|B) = 1/4, P(C|A) = 1/2,<br>
# P(C) = P(C ∩ A) + P(C ∩ B),<br>
# P(A ∩ C) = P(C|A) P(A)  = 1/2 . 1/300 = 1/600,<br>
# P(B ∩ C) = P(C|B) P(B)  = 1/4 . 1/125 = 1/500.<br>
# Calcule P(A|C).<br>
#
# Assinale a alternativa que melhor representa as respostas para (a) e (b).<br>
#
# Escolha uma opção:<br>
# a. 5/11 e verossimilhança<br>
# <font color='red'>b. 5/11 e distribuição a priori</font><br>
# c. 6/11 e distribuição a posteriori<br>
# d. 8/11 e distribuição a posteriori<br>
# e. 4/11 e verossimilhança<br>
# f. 7/11 e verossimilhança<br>
# g. 4/11 e distribuição a posteriori<br>
# h. 4/11 e distribuição a priori<br>
# i. 7/11 e distribuição a priori<br>

# %% [markdown]
# a-<br>
# probabilidade condicional:<br>
# P(A|C) = P(A ∩ C) / P(C)<br>
# P(A|C) = P(C ∩ A) / P(C)<br>
# P(A|C) = 1/600 / (1/600 + 1/500)<br>
# P(A|C) = 1/600 / (5/3000 + 6/3000)<br>
# P(A|C) = 1/600 / (11/3000) = 3000 / (600*11) = 5/11<br>
#
# teorema de bayes:<br>
# P(A|C): distribuição à priori
# P(C|A): distribuição da verossimilhança
# P(A): distribuição à priori
# P(C): constante normalizadora
#
# P(A|C) = P(C|A) * P(A) / P(C) <br>
# P(A|C) = 1/2 * 1/300 / (1/600 + 1/500)<br>
# P(A|C) = 1/600 / (1/600 + 1/500)<br>
# P(A|C) = 1/600 / (5/3000 + 6/3000)<br>
# P(A|C) = 1/600 / (11/3000) = 3000 / (600*11) = 5/11<br>
#
# b-distribuição a priori

# %% [markdown]
# ### Questão 4:<br>
# Uma análise Bayesiana foi desenvolvida utilizando o pacote PYMC3 do Python.<br>
# Assinale os itens que NÃO estão representados nos gráficos abaixo.
#
# ![AS6_questao4.png](attachment:AS6_questao4.png)
#
# Escolha uma ou mais:<br>
# a. intervalos de credibilidade para os parâmetros obtidos com 4 cadeias simuladas<br>
# <font color='red'>b. moda da distribuição a posteriori</font><br>
# <font color='red'>c. densidades a priori</font><br>
# d. estatística R chapéu indicando a convergência do método<br>
# e. estimativas pontuais e intervalares para os parâmetros<br>
# f. densidades a posteriori<br>

# %% [markdown]
# a-ok
# b-nok   - apenas a média é explicitada
# c-nok   - todos os dados se referem à posteriori
# d-ok
# e-ok
# f-ok

# %% [markdown]
# ### Questão 5:<br>

# %% [markdown]
# ![AS6_questao5.png](attachment:AS6_questao5.png)

# %% [markdown]
# Considere o modelo linear generalizado estudado em https://docs.pymc.io/notebooks/GLM-poisson-regression.html com o pacote PYMC3. Embora este modelo ainda não tenha sido explorado neste curso, com os conhecimentos adquiridos até o momento, é possível afirmar que:<br>
#
# I - Os dados seguem uma distribuição de Poisson.<br>
# II - São assumidas distribuições a priori pouco informativas para os parâmetros.<br>
# III - O modelo conjugado Gamma-Poisson é utilizado.<br>
# IV - O código usa programação probabilística.<br>
# V - O pacote PYMC3 possui métodos implementados para obter amostras da distribuição a posteriori dos parâmetros.<br>
#
# Estão corretos os itens:<br>
# Escolha uma opção:<br>
# a. I e III apenas<br>
# b. todos<br>
# c. II e III apenas<br>
# d. I e II apenas<br>
# e. I, II e III apenas<br>
# <font color='red'>f. I, II, IV e V apenas</font><br>
# g. I, II, III e IV apenas<br>

# %% [markdown]
# I-ok   <br>
# Os dados da amostra (verossimilhança) seguem uma distribuição de Poisson.<br>
# verossimilhança = plausabilidade = likelihood<br>
# Possion regression: θ=exp(βX)<br>
# y = pm.Poisson("y", mu, observed)<br>
# pm.Poisson(mu)   <br>
# mu: float, Expected number of occurrences during the given interval (mu >= 0)<br>
# mu: trás as informações da função de distribuição da priori<br>
# observed: trás as informações da verossimilhança, são os dados observados, número de espirros<br>
#
# II-ok   <br>
# Existem informações de uma distribuição priori Normal: pm.Normal(), com todos os parâmetros mu=0, sigma=10, que é um sigma teoricamente alto (calcular a relação sigma/mu nesse caso não é possível pois mu=0). A rigor seria necessário conhecer melhor os dados, mas há uma observação na linha de definição da priori de que as informações são fracas ("weakly informative Normal").<br>
#
# III-nok  <br>
# É usada uma distribuição Normal para a priori (pm.Normal) e uma distribuição de poisson para a verossimilhança (pm.Poisson), portanto o modelo é Normal-Poisson <br>
# Modelo conjugado: mesma distribuição para a priori e a posteriori <br>
#
# IV-ok   <br>
# A inferência bayesiana usa as distribuições de probabilidades e é o que se vê no código.<br>
# O oposto seria a inferência clássica ou frequentista que determinaria o valor esperado após um número infinito de amostragens.<br>
#
# V-ok   <br>
# O pacote pymc3 possui diversos modelos para amostragem dos dados da priori.<br>
